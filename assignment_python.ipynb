# %% [raw]
# # Python Baiscs  Assignment #
#
#
# 1.Explain the key features of Python that make it a popular choice for programming.
#
# Ans. * Python is easy to understand and readability and easy to code.
# *Python has a vast and continuously growing ecosystem of libraries. The total number of python libraries are more than. 137000 libraries
# * Python is a open source programming language hence anybody can develop and develop and improve the language.
# *Python is a higher level programming language which means when you write code in it you don't have to worry about its architecture, memory management  or structure of code.
# *Python includes a large number of libraries that may be imported at any moment and used in a specific program . you don't have to write all the codes yourself because you'll be able to import from the existing libraries .
# *Python is the best language for machine learning. Because it’s simple to understand, data validation is quick and error-free. Developers can do difficult operations without coding since they have access to a well-developed library ecosystem.

# %% [raw]
# #2.Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# #Ans In Python, predefined keywords are reserved words that have special meanings  to the language's syntax. These keywords cannot be used as identifiers (e.g., variable names, function names) because they are reserved by Python for specific functionalities.Their are 36 predefined keywords in python (False, True, None, and, as, assert, async, await, def, del, elif, else, break, class, continue, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with and yield.)
#
# #.These keywords are used for conditional statements.
# a = 11
# if a > 5:
# 	print("a is greater than 5")
# elif a == 5:
# 	print("a is equal to 5")
# else:
# 	print("a is less than 5")

# %% [raw]
#  #3.Compare and contrast mutable and immutable objects in Python with examples
#  #Ans.n Python, objects can be classified into two categories based on whether their state (i.e., the data they hold) can be changed after they are created: mutable and immutable objects.
#
#  #* Mutable Objects
# #- Definition: Mutable objects are those whose state or content can be changed after they are created.
# #- Examples: Lists, dictionaries, sets, and most custom objects.
# #- Behavior: Operations that modify mutable objects, such as appending to a list or updating a dictionary, change the object in place, without creating a new object.
#
# #Example with a List (Mutable object)
# mutable_list = [ 11, 22, 33, 44,77]
# mutable_list[4] = 21
# mutable_list.append(5)
# print(mutable_list)
# ##################################
# #Immutable objects are those whose state or content cannot be changed after they are created
# #example of immutable object
#
# my_string = "pizza, burger!"
# new_string="protien", "Powder"
# my_string.replace("protien", "Powder")
# print("Original string:", my_string)
# print("New string:", new_string)
# # Mutable objects can save memory because they can be changed in place. Immutable objects, however, require creating new objects for every modification, which can be less memory efficient in some cases.
# #Immutable objects are hashable, meaning they can be used as keys in a dictionary or elements in a set. Mutable objects are generally not hashable because their hash value can change if the object is modified

# %% [raw]
#  #4.Discuss the different types of operators in Python and provide examples of how they are used ?
# #Ans In Python, operators are special symbols that perform operations on variables and values. Python provides a rich set of operators, there are 7 types of operator which can be categorized into several types:
# #1.Airthmetic operators
# #2.Assignment operators
# #3.logical operators
# #4.birwise operators
# #5.identity operators
# #6.membership  operators
# #7.Comparison (Relational) Operators
#
#  Airthmetic operators
#
# - Addition (`+`): Adds two operands.
#    a = 4
#   b =6
#   result = a + b  # result is 10
#
# - Subtraction (`-`): Subtracts the right operand from the left operand.
#    result = a - b  # result is 2
#
# - Multiplication (`*`): Multiplies two operands.
#    result = a * b  # result is 24
#
# - Division (`/`): Divides the left operand by the right operand.
#    result = a / b  # result is 0.66
#
# - Modulus (`%`): Returns the remainder of the division.
#    result = a % b  # result is 1
#
# - Exponentiation (`**`): Raises the left operand to the power of the right operand.
#    result = a ** b  # result is 4096
#
# - Floor Division (`//`): Divides and returns the largest integer less than or equal to the quotient.
#    result = a // b  # result is 1
#
#
#     2. Comparison (Relational) Operators
# These operators compare the values of two operands and return True or False.
#
# - Equal to (`==`): Checks if the values of two operands are equal.
#    result = (a == b)  # result is False
#
# - Not equal to (`!=`): Checks if the values of two operands are not equal.
#    result = (a != b)  # result is True
#
# - Greater than (`>`): Checks if the left operand is greater than the right operand.
#    result = (a > b)  # result is True
#
# - Less than (`<`): Checks if the left operand is less than the right operand.
#    result = (a < b)  # result is False
#
# - Greater than or equal to (`>=`): Checks if the left operand is greater than or equal to the right operand.
#    result = (a >= b)  # result is True
#
# - Less than or equal to (`<=`): Checks if the left operand is less than or equal to the right operand.
#    result = (a <= b)  # result is False
#
#  3. Logical Operators
# Logical operators are used to combine conditional statements.
#
# - AND (`and`): Returns True if both statements are true.
#    result = (a > b) and (a == 10)  # result is True
#
# - OR (`or`): Returns True if one of the statements is true.
#    result = (a < b) or (a == 10)  # result is True
#
# - NOT (`not`): Reverses the result, returns False if the result is true.
#    result = not(a == 10)  # result is False
#
#  4. Assignment Operators
# These operators are used to assign values to variables.
#
# - Assignment (`=`): Assigns the value on the right to the variable on the left.
#    c = a + b  # c is 15
#
# - Add and assign (`+=`): Adds the right operand to the left operand and assigns the result to the left operand.
#    c += a  # c is 25
#
# - Subtract and assign (`-=`): Subtracts the right operand from the left operand and assigns the result to the left operand.
#    c -= b  # c is 20
#
# - Multiply and assign (`*=`): Multiplies the right operand with the left operand and assigns the result to the left operand.
#    c *= b  # c is 100
#
# - Divide and assign (`/=`): Divides the left operand by the right operand and assigns the result to the left operand.
#    c /= a  # c is 10.0
#
# - Modulus and assign (`%=`): Takes modulus using two operands and assigns the result to the left operand.
#    c %= a  # c is 0.0
#
#  5. Bitwise Operators
# These operators are used to perform bit-level operations.
#
# - AND (`&`): Performs bitwise AND.
#    result = a & b  # result is 0
#
# - OR (`|`): Performs bitwise OR.
#    result = a | b  # result is 15
#
# - XOR (`^`): Performs bitwise XOR.
#    result = a ^ b  # result is 15
#
# - NOT (`~`): Performs bitwise NOT.
#    result = ~a  # result is -11
#
# - Left Shift (`<<`): Shifts bits to the left.
#    result = a << 1  # result is 20
#
# - Right Shift (`>>`): Shifts bits to the right.
#    result = a >> 1  # result is 5
#
#  6. Membership Operators
# These operators test for membership in a sequence, such as strings, lists, or tuples.
#
# - In (`in`): Returns True if the value is found in the sequence.
#    result = 'H' in 'Hello'  # result is True
# - Not in (`not in`): Returns True if the value is not found in the sequence.
#    result = 'X' not in 'Hello'  # result is True
#
# 7. Identity Operators
# These operators compare the memory locations of two objects.
#
# - Is (`is`): Returns True if both variables point to the same object.
#    a = [1, 2, 3]
#   b = a
#   result = (a is b)  # result is True
#
# - Is not (`is not`): Returns True if both variables point to different objects.
#    c = a.copy()
#   result = (a is not c)  # result is True

# %% [raw]
#  5.  Explain the concept of type casting in Python with examples
#
# Ans  Type casting in Python refers to the conversion of one data type into another. This is useful when you need to perform operations that require a specific data type. Python provides several built-in functions for type casting, allowing you to convert data types explicitly.
# Types of Type Casting
# 1. Implicit Type Casting
# 2. Explicit Type Casting
#
#  1. Implicit Type Casting
#
# In implicit type casting, Python automatically converts one data type into another without any explicit instruction from the user. This usually happens in cases where the conversion is safe and does not result in data loss.
#
#  Example:a = 10
# b = 2.5
#
# # Adding integer and float; Python converts 'a' to float automatically
# c = a + b
#
# print(type(c))  # Output: <class 'float'>
# print(c)  # Output: 12.5
#
# In the example above, Python automatically converts the integer a into a float before performing the addition, resulting in a float c.
#
# 2. Explicit Type Casting
#
# Explicit type casting involves manually converting one data type into another using Python's built-in functions. This is useful when you want to control the conversion process, especially when dealing with incompatible types.
#
#  Common Type Casting Functions:
#
# - int(): Converts a value to an integer.
# - float(): Converts a value to a float.
# - str(): Converts a value to a string.
# - list(): Converts a value to a list.
# - tuple(): Converts a value to a tuple.
# - dict(): Converts a value to a dictionary.
# - set(): Converts a value to a set.
#
#  #Example 1: String to Integer = "123"  # String b = int(a)  # Explicitly convert string to integer
# num = '10'
# print(type(num))
# converted_num = int(num)
# print(type(converted_num))
# print(converted_num + 20)
#
# In this example, the string "123" is explicitly converted to an integer using the int() function.
#
#  Example 2: Float to Integer = 5.7  # Float
# b = int(a)  # Explicitly convert float to integer
#
# print(type(b))  # Output: <class 'int'>
# print(b)  # Output: 5
#
# Here, the float 5.7 is explicitly converted to an integer using the int() function, resulting in the value 5 (note that the decimal part is truncated, not rounded).
#
#  Example 3: Integer to Stringa = 10  # Integer
# b = str(a)  # Explicitly convert integer to string
#
# print(type(b))  # Output: <class 'str'>
# print(b)  # Output: '10'
#
# In this case, the integer 10 is explicitly converted to a string using the str() function.
#
#  Example 4: List to Tuplea = [1, 2, 3]  # List
# b = tuple(a)  # Explicitly convert list to tuple
#
# print(type(b))  # Output: <class 'tuple'>
# print(b)  # Output: (1, 2, 3)
#
# Here, a list is converted to a tuple using the tuple() function

# %% [raw]
# #6. How do conditional statements work in Python? Illustrate with examples
# #Ans Conditional statements in Python allow you to execute specific blocks of code based on certain conditions. These statements are fundamental in controlling the flow of a program, enabling decision-making and branching.
#
# Types of Conditional Statements in Python:
#
# 1. `if` Statement
# 2. `if-else` Statement
# 3. `if-elif-else` Statement
# 4. Nested `if` Statement
#
# 1. if Statement
#
# The if statement is the simplest form of a conditional statement. It checks a condition, and if the condition is True, it executes the block of code indented under it.
#
#   Syntax:if condition:
#     # Code to execute if the condition is True
#
#   Example:age = 18
#
# if age >= 18:
#     print("You are eligible to vote.")
#
# Output:
# You are eligible to vote.
#
# Here, the condition age >= 18 evaluates to True, so the code inside the if block is executed.
#
#   2. if-else Statement
#
# The if-else statement allows you to execute one block of code if the condition is True and another block of code if the condition is False.
#
#   Syntax:if condition:
#     # Code to execute if the condition is True
# else:
#     # Code to execute if the condition is False
#
#   Example:age = 16
#
# if age >= 18:
#     print("You are eligible to vote.")
# else:
#     print("You are not eligible to vote.")
#
# Output:
# You are not eligible to vote.
#
# In this case, the condition age >= 18 is False, so the code inside the else block is executed.
#
#   3. if-elif-else Statement
#
# The if-elif-else statement is used when you have multiple conditions to check. The elif (short for "else if") allows you to check multiple conditions sequentially. Once a condition is found to be True, its corresponding block of code is executed, and the rest are skipped.
#
#   Syntax:if condition1:
#     # Code to execute if condition1 is True
# elif condition2:
#     # Code to execute if condition2 is True
# else:
#     # Code to execute if all conditions are False
#
#   Example:marks = 75
#
# if marks >= 90:
#     print("Grade: A")
# elif marks >= 80:
#     print("Grade: B")
# elif marks >= 70:
#     print("Grade: C")
# else:
#     print("Grade: D")
#
# Output:
# Grade: C
#
# Here, the first two conditions (`marks >= 90` and marks >= 80`) are `False, but the third condition (`marks >= 70`) is True, so the corresponding block is executed.
#
#   4. Nested if Statement
#
# You can also nest if statements within other if statements. This allows for more complex decision-making.
#
#   Syntax:if condition1:
#     # Outer if statement
#     if condition2:
#         # Nested if statement
#         # Code to execute if condition2 is True
#
#    Example:age = 20
# citizenship = "Indian"
#
# if age >= 18:
#     if citizenship == "Indian":
#         print("You are eligible to vote in India.")
#     else:
#         print("You are not an Indian citizen.")
# else:
#     print("You are not eligible to vote.")
#
# Output:
# You are eligible to vote in India.

# %% [raw]
# #7. Describe the different types of loops in Python and their use cases with examples
# Ans In Python, loops are used to repeatedly execute a block of code as long as a specified condition is met. Python supports two main types of loops: for loops and while loops. Each type of loop has its specific use cases, and understanding them allows you to perform repetitive tasks efficiently.
#
# # 1. for Loop
#
# The for loop is used for iterating over a sequence (such as a list, tuple, dictionary, set, or string) or other iterable objects. The loop iterates over each item in the sequence and executes the block of code for each item.
#
# # Syntax:for variable in sequence:
#     # Code to execute for each item in the sequence
#
# # Example 1: Iterating Over a Listfruits = ["apple", "banana", "cherry"]
#
# for fruit in fruits:
#     print(fruit)
#
# Output:
# apple
# banana
# cherry
#
# In this example, the for loop iterates over the list fruits and prints each fruit.
#
# # Example 2: Using range() with a for Loopfor i in range(5):
#     print(i)
#
# Output:
# 0
# 1
# 2
# 3
# 4
#
# The range() function generates a sequence of numbers from 0 to 4, and the for loop iterates over this sequence, printing each number.# Use Cases for for Loops:
# - Iterating over elements in a list, tuple, or string.
# - Executing a block of code a specific number of times using range().
# - Iterating over keys or key-value pairs in a dictionary.
#
# # 2. while Loop
#
# The while loop executes a block of code as long as a specified condition is True. It is often used when the number of iterations is not known in advance and depends on a condition being met during runtime.
#
# # Syntax:while condition:
#     # Code to execute as long as the condition is True
#
# # Example 1: Counting Downcount = 5
#
# while count > 0:
#     print(count)
#     count -= 1
#
# Output:
# 5
# 4
# 3
# 2
# 1
#
# In this example, the while loop continues to execute as long as count is greater than 0. After each iteration, count is decremented by 1.
#
# # Example 2: Using while Loop with a User Inputuser_input = ""
#
# while user_input.lower() != "quit":
#     user_input = input("Enter something (or 'quit' to exit): ")
#     print("You entered:", user_input)
#
# In this example, the loop will continue asking for user input until the user types "quit".
#
# # Use Cases for while Loops:
# - Running a loop until a certain condition changes (e.g., waiting for user input, processing data until a certain condition is met).
# - Implementing infinite loops (with a break condition inside the loop).
# - When the number of iterations is not predetermined.
#
# # 3. Nested Loops
#
# Both for and while loops can be nested within each other. This means you can have a loop inside another loop, allowing for more complex iterations.
#
# # Example: Nested for Loopfor i in range(3):
#     for j in range(2):
#         print(f"i = {i}, j = {j}")
#
# Output:
# i = 0, j = 0
# i = 0, j = 1
# i = 1, j = 0
# i = 1, j = 1
# i = 2, j = 0
# i = 2, j = 1
#
# In this example, the outer for loop iterates over the range 0 to 2, and for each iteration of the outer loop, the inner for loop iterates over the range 0 to 1.
#
# # Use Cases for Nested Loops:
# - Iterating over multi-dimensional data structures (e.g., a list of lists).
# - Performing operations that require checking pairs or combinations of elements.
# - Simulating grid or matrix operations.
# # 4. break and continue Statements
#
# - `break`: Exits the loop prematurely, stopping all further iterations.
#
#   #### Example:
#    for i in range(5):
#       if i == 3:
#           break
#       print(i)
#
#   Output:
#    0
#   1
#   2
#
#   The loop stops when i equals 3, exiting the loop using the break statement.
#
# - `continue`: Skips the current iteration and moves on to the next iteration of the loop.
#
#   # Example:
#    for i in range(5):
#       if i == 3:
#           continue
#       print(i)
#
#   Output:
#    0
#   1
#   2
#   4
#
#   The loop skips printing i when i equals 3 due to the continue
